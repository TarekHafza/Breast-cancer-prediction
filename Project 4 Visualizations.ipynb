# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('BC_ML_tbl.csv')
df.head()
# Out:
#       id Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   8670         M        15.46         19.48          101.70      748.9
# 1   8913         B        12.89         13.12           81.89      515.9
# 2   8915         B        14.96         19.10           97.03      687.3
# 3   9047         B        12.94         16.17           83.18      507.6
# 4  85715         M        13.17         18.66           85.98      534.6
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.10920           0.12230         0.14660              0.08087
# 1          0.06955           0.03729         0.02260              0.01171
# 2          0.08992           0.09823         0.05940              0.04819
# 3          0.09879           0.08836         0.03296              0.02390
# 4          0.11580           0.12310         0.12260              0.07340
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
sns.violinplot(x='radius_mean', y='texture_mean', data=df, hue='Diagnosis', split=True)
# Out:
# <AxesSubplot:xlabel='radius_mean', ylabel='texture_mean'>

# %%
df['texture_mean_binned'] = pd.cut(df['texture_mean'], bins=3, labels=["Low", "Medium", "High"])
df['smoothness_mean_binned'] = pd.cut(df['smoothness_mean'], bins=3, labels=["Low", "Medium", "High"])
df_fg = sns.FacetGrid(df, col='texture_mean_binned', row='smoothness_mean_binned')
df_fg.map(plt.hist, 'Diagnosis', bins=10)
